# %%
from pathlib import Path
import numpy as np
from astropy.io import fits
from PIL import Image
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#with fits.open("/home/bekah/m3_papers/20260319/m3g20090529t015004_l0.fits") as hdul:
#    data = hdul[0].data 
with fits.open("/home/bekah/m3_papers/m3g20090617t045633_l0.fits") as hdul:
    data = hdul[0].data

# %%
n_frames, n_time, n_cols = data.shape
time_axis = np.arange(n_time)

# %%
plt.figure(figsize=(15, 10))

plt.scatter(time_axis, data[35, :, 4], color='b', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[35, :, 319], color='r', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[84, :, 319], color='g', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[75, :, 3], color='y', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[63, :, 318], color='g', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[55, :, 120], color='m', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[24, :, 154], color='c', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[15, :, 78], color='r', alpha=0.5, linewidth=0.2)

# %%
with fits.open("/home/bekah/m3_papers/260308_darkcurrent_gifs/dark_current_images/m3g20090626t182643_l0.fits") as hdul:
    data = hdul[0].data  # shape: (NAXIS3, NAXIS2, NAXIS1) = (86, 21910, 320)

# %%
plt.scatter(time_axis, data[35, :, 4], color='b', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[35, :, 3], color='r', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[64, :, 319], color='g', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[64, :, 180], color='k', alpha=0.5, linewidth=0.2)
plt.scatter(time_axis, data[64, :, 3], color='c', alpha=0.5, linewidth=0.2)
