# %%
# the hdr files from the original m3 delivery need to be scraped for info on their helper files: 
# this info, _RDN.HDR
temperature =       146.12
beta angle =        59.73
dark signal image = M3G20090416T080701_V01_L0.IMG           
bad detector element map = M3G20090416T080701_V01_BDE.IMG            
flat field image = M3G20090416T081001_V01_FF.IMG

# %%
import pyarrow.parquet as pq 
import pandas as pd

# %%
df = pq.read_table("/home/bekah/pdr-tests/pdr_tests/node_manifests/img_usgs_chandrayaan_1.parquet").to_pandas()

# %%
df
# Out:
#                                                  domain  \
# 0      asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# 1      asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# 2      asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# 3      asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# 4      asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# ...                                                 ...
# 23524  asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# 23525  asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# 23526  asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# 23527  asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
# 23528  asc-pds-chandrayaan-1.s3.us-west-2.amazonaws.com
#
#                           url                            filename        size  \
# 0                                               bundle_ch1_m3.xml        6538
# 1                                                      m3_md5.csv     2217562
# ...
